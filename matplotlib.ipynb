# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df= np.arange(0,100)

plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4])
plt.show()

# %%
x=[1,2,3,4,5]
y=[11,22,33,44,55]
plt.plot(x,y)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot()
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x,[10,25,35,40,60])
plt.show()

# %%
type(fig) , type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %% [markdown]
# ## matplot lib example workflow

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

#prepare data
x= [1,2,3,4]
y=[11,22,33,44]
#set up plot
fig, ax = plt.subplots(figsize=(2,2))
#plot data
ax.plot(x,y)
#customise plot
ax.set(title="simple plot",xlabel="x-axis",ylabel="y-label")
#save plot
fig.savefig("../ztmDS/zero-to-mastery-ml-master/zero-to-mastery-ml-master/images/simpleplot.jay.png")
#print plot
plt.show()

# %% [markdown]
# ## scatterplot and bar plot

# %%
x = np.linspace(0,10,10)
x
# Out:
# array([ 0.        ,  1.11111111,  2.22222222,  3.33333333,  4.44444444,
#         5.55555556,  6.66666667,  7.77777778,  8.88888889, 10.        ])

# %%
fig , ax = plt.subplots()
ax.plot(x,x**2)
plt.show()

# %%
#line , scatter ,bar, hist , subplots
fig , ax = plt.subplots()
ax.scatter(x,np.exp(x))
plt.show()

# %%
#sin scatter
x = np.linspace(0,10,100)
fig , ax = plt.subplots()
ax.scatter(x,np.sin(x))
plt.show()

# %%
#from dictionaries
butter_prices = {"almond":10,"peanut":8,"cashew":12}
fig, ax = plt.subplots()
ax.set(title="butter store",xlabel="butter",ylabel="prices")
ax.bar(butter_prices.keys(),butter_prices.values())
plt.show()

# %% [markdown]
# ## histograms and subplots

# %%
#from dictionaries
butter_prices = {"almond":10,"peanut":8,"cashew":12}
fig, ax = plt.subplots()
ax.set(title="butter store",xlabel="butter",ylabel="prices")
# ax.barh(butter_prices.keys(),butter_prices.values())
ax.barh(list(butter_prices.keys()),list(butter_prices.values()))

plt.show()

# %%
#histogram
x= np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x)
plt.show()

# %% [markdown]
# # subplots

# %%
#option 1
fig , ((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(10,5))

#plot to different axis
ax1.plot(x,x/2)
ax2.scatter(np.random.random(10),np.random.random(10))
ax3.bar(butter_prices.keys(),butter_prices.values())
ax4.hist(butter_prices.values())
plt.show()

# %%
# option 2

fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(10,5))

#plot to index

ax[0,0].plot(x,x/2)
ax[0,1].scatter(np.random.random(10),np.random.random(10))
ax[1,0].bar(butter_prices.keys(),butter_prices.values())
ax[1,1].hist(butter_prices.values())
plt.show()

# %%
ts = pd.Series(np.random.randn(1000),index=pd.date_range("1/1/2023",periods=1000))
ts = ts.cumsum()
ts.plot()
plt.show()

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
carsales = pd.read_csv("car-sales1.csv")
carsales["Price"] = pd.to_numeric(carsales["Price"].str.replace('[\$\,]',"",regex=True))
carsales["Price"].dtype
carsales["sale date"] = pd.date_range("01/01/2023",periods=len(carsales))
carsales["total"] = carsales["Price"].cumsum().astype(int)
carsales
carsales.plot(x="sale date",y="total")
plt.show()

# fig , ax = plt.subplots()
# ax.bar(carsales)
# plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\$'
# <>:5: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\Sanjay B\AppData\Local\Temp\ipykernel_27380\1046596883.py:5: SyntaxWarning: invalid escape sequence '\$'
#   carsales["Price"] = pd.to_numeric(carsales["Price"].str.replace('[\$\,]',"",regex=True))

# %%
carsales
carsales.plot(x="Odometer (KM)",y="Price",kind="scatter")
plt.show()

# %%
carsales["Odometer (KM)"].dtypes
carsales
carsales.plot(x="sale date", y="total",kind="box")
plt.show()

# %%
np.random.seed(0)
x = np.random.rand(10,4)
x

df = pd.DataFrame(x,columns=["a","b","c","d"])
df.plot.bar()
df.plot(kind="bar")
plt.show()

# %%
carsales.plot(x="Make",y="Odometer (KM)",kind="bar")
# carsales
plt.show()

# %%
#histogram
carsales["Odometer (KM)"].plot(kind="hist")
# carsales
plt.show()

# %%
#histogram
carsales["Odometer (KM)"].plot.hist(bins=5)
# carsales
plt.show()

# %%
#another dataset

heart_disease = pd.read_csv("heart-disease.csv")
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heart_disease["age"].plot.hist(color="skyblue")
plt.show()

# %%
heart_disease.plot.hist(figsize=(2,20),subplots=True)
heart_disease.plot.hist()

plt.show()

# %%
## which method to use ? pyplot vs matplotlib oo method?

# when plotting something quick use pyplot
# if plotting something advanced , use oo method

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50 = heart_disease[heart_disease["age"]>50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
over_50.plot(kind="scatter",x="age",y="chol",c="target")
plt.show()

# %%
fig , ax = plt.subplots(figsize=(10,6))
over_50.plot(kind="scatter",x="age",y="chol",c="target",ax=ax)
ax.set_xlim([45,100])
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

scatter = ax.scatter(x=over_50["age"],y=over_50["chol"],c=over_50["target"])

ax.set(title="heart disease and cholestrol level", xlabel="age",ylabel="cholestrol")

ax.legend(*scatter.legend_elements(),title="target")


ax.axhline(over_50["chol"].mean(), linestyle="--")

plt.show()

# %%
fig , (ax0,ax1) = plt.subplots(nrows=2,ncols=1,figsize=(10,10),sharex=True)

scatter = ax0.scatter(x=over_50["age"],y=over_50["chol"],c=over_50["target"])

#customise ax0
# ax0.set(title="heart disease and cholestrol levels",xlabel="age",ylabel="chol")
ax0.set(title="heart disease and cholestrol levels",ylabel="chol")


#legend
ax0.legend(*scatter.legend_elements(),title="target")
ax0.axhline(y=over_50["chol"].mean(),linestyle="--")


#adding data to ax1
scatter = ax1.scatter(x=over_50["age"],y=over_50["thalach"],c=over_50["target"])

ax1.set(title="heart disease and max heart rate",xlabel="age",ylabel="max heart rate")

ax1.legend(*scatter.legend_elements(),title="target")
ax1.axhline(y=over_50["thalach"].mean(),linestyle="--")


# add title to fig

fig.suptitle("heart disease Analysis",fontsize=16, fontweight="bold")

plt.show()

# %% [markdown]
# ## customising plots

# %%
plt.style.available
plt.style.use("seaborn-v0_8-whitegrid")
carsales["Price"].plot(figsize=(3,3))

plt.show()

# %%
plt.style.use("seaborn-v0_8")
carsales["Price"].plot(figsize=(3,3))


plt.show()
# plt.style.available

# %%
carsales.plot(x=["Odometer (KM)"],y=["Price"],kind="scatter")
plt.show()

# %%
plt.style.available
plt.style.use("ggplot")
carsales["Price"].plot(figsize=(3,3))
plt.show()

# %%
random_values = np.random.rand(10,4)
df = pd.DataFrame(random_values,columns=["a","b","c","d"])

ax=df.plot(kind="bar")
ax.set(title="random bar graph",xlabel="row num",ylabel="random")
ax.legend().set_visible(True)
plt.show()
